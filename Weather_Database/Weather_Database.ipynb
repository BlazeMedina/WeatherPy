# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000, size=2000)
lngs = np.random.uniform(-90.000,90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
from citipy import citipy
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_w_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_w_des})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | voisiku
# City not found. Skipping...
# Processing Record 2 of Set 1 | garowe
# Processing Record 3 of Set 1 | krasnoshchekovo
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | fuengirola
# Processing Record 6 of Set 1 | husavik
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | ponta do sol
# Processing Record 11 of Set 1 | cap malheureux
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | kavaratti
# Processing Record 14 of Set 1 | sinnar
# Processing Record 15 of Set 1 | yar-sale
# Processing Record 16 of Set 1 | kathmandu
# Processing Record 17 of Set 1 | hatta
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | castro
# Processing Record 20 of Set 1 | maragogi
# Processing Record 21 of Set 1 | melioratorov
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | sechura
# Processing Record 26 of Set 1 | codrington
# Processing Record 27 of Set 1 | muborak
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | anar darreh
# City not found. Skipping...
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | vila velha
# Processing Record 32 of Set 1 | witzenhausen
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | synya
# Processing Record 35 of Set 1 | bolshaya dzhalga
# Processing Record 36 of Set 1 | honningsvag
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | lagoa
# Processing Record 40 of Set 1 | itarema
# Processing Record 41 of Set 1 | teya
# Processing Record 42 of Set 1 | panjwin
# City not found. Skipping...
# Processing Record 43 of Set 1 | akhmeta
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 1 | biddeford
# Processing Record 47 of Set 1 | kaiserslautern
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | hermanus
# Processing Record 50 of Set 1 | pangnirtung
# Processing Record 1 of Set 2 | rodrigues alves
# Processing Record 2 of Set 2 | bali
# Processing Record 3 of Set 2 | waddan
# Processing Record 4 of Set 2 | surt
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | kourou
# Processing Record 7 of Set 2 | west bay
# Processing Record 8 of Set 2 | aksarka
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | elizabeth city
# Processing Record 11 of Set 2 | filingue
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | salinopolis
# Processing Record 14 of Set 2 | pagondas
# City not found. Skipping...
# Processing Record 15 of Set 2 | road town
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | kandri
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | ribeira grande
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | sekoma
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | susangerd
# Processing Record 24 of Set 2 | vila franca do campo
# Processing Record 25 of Set 2 | ferrol
# Processing Record 26 of Set 2 | rio grande
# Processing Record 27 of Set 2 | ust-ishim
# Processing Record 28 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 2 | ambilobe
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 35 of Set 2 | fasa
# Processing Record 36 of Set 2 | eha amufu
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 2 | mahdasht
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | klaksvik
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | oistins
# Processing Record 44 of Set 2 | saint-augustin
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | mayor pablo lagerenza
# Processing Record 47 of Set 2 | port blair
# Processing Record 48 of Set 2 | havre-saint-pierre
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | vardo
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | dikson
# Processing Record 5 of Set 3 | grao mogol
# Processing Record 6 of Set 3 | vestmannaeyjar
# Processing Record 7 of Set 3 | vodnyy
# Processing Record 8 of Set 3 | jablonne nad orlici
# Processing Record 9 of Set 3 | los rastrojos
# Processing Record 10 of Set 3 | rossano
# Processing Record 11 of Set 3 | salalah
# Processing Record 12 of Set 3 | saint anthony
# Processing Record 13 of Set 3 | manaquiri
# Processing Record 14 of Set 3 | oudtshoorn
# Processing Record 15 of Set 3 | vorukh
# Processing Record 16 of Set 3 | hornepayne
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | lundazi
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | riohacha
# Processing Record 21 of Set 3 | minas
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | deh rawud
# City not found. Skipping...
# Processing Record 24 of Set 3 | mutare
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | la asuncion
# Processing Record 27 of Set 3 | nemours
# Processing Record 28 of Set 3 | linhares
# Processing Record 29 of Set 3 | urumqi
# Processing Record 30 of Set 3 | niksic
# Processing Record 31 of Set 3 | talawdi
# City not found. Skipping...
# Processing Record 32 of Set 3 | mitsamiouli
# Processing Record 33 of Set 3 | taltal
# Processing Record 34 of Set 3 | sao raimundo nonato
# Processing Record 35 of Set 3 | stephenville
# Processing Record 36 of Set 3 | maldonado
# Processing Record 37 of Set 3 | mount pleasant
# Processing Record 38 of Set 3 | irpa irpa
# Processing Record 39 of Set 3 | espanola
# Processing Record 40 of Set 3 | karaton
# Processing Record 41 of Set 3 | grindavik
# Processing Record 42 of Set 3 | domoni
# Processing Record 43 of Set 3 | saint-joseph
# Processing Record 44 of Set 3 | mehamn
# Processing Record 45 of Set 3 | beloha
# Processing Record 46 of Set 3 | awbari
# Processing Record 47 of Set 3 | buncrana
# Processing Record 48 of Set 3 | turbat
# Processing Record 49 of Set 3 | inirida
# Processing Record 50 of Set 3 | sambava
# Processing Record 1 of Set 4 | gondar
# Processing Record 2 of Set 4 | eslamshahr
# Processing Record 3 of Set 4 | acarau
# Processing Record 4 of Set 4 | gornopravdinsk
# Processing Record 5 of Set 4 | rio gallegos
# Processing Record 6 of Set 4 | padilla
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | brigantine
# Processing Record 9 of Set 4 | shu
# Processing Record 10 of Set 4 | chissamba
# Processing Record 11 of Set 4 | torres
# Processing Record 12 of Set 4 | marawi
# Processing Record 13 of Set 4 | jadu
# Processing Record 14 of Set 4 | beyneu
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | ampanihy
# Processing Record 17 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 4 | araouane
# Processing Record 19 of Set 4 | oranjestad
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | mitu
# Processing Record 22 of Set 4 | hare bay
# Processing Record 23 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 4 | abu samrah
# Processing Record 25 of Set 4 | torbay
# Processing Record 26 of Set 4 | leshukonskoye
# Processing Record 27 of Set 4 | ilo
# Processing Record 28 of Set 4 | tahoua
# Processing Record 29 of Set 4 | margate
# Processing Record 30 of Set 4 | atasu
# Processing Record 31 of Set 4 | chinsali
# Processing Record 32 of Set 4 | halifax
# Processing Record 33 of Set 4 | atar
# Processing Record 34 of Set 4 | mahibadhoo
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | murgab
# Processing Record 37 of Set 4 | tahta
# Processing Record 38 of Set 4 | rovnoye
# Processing Record 39 of Set 4 | meulaboh
# Processing Record 40 of Set 4 | bambous virieux
# Processing Record 41 of Set 4 | shubarkuduk
# Processing Record 42 of Set 4 | suwalki
# Processing Record 43 of Set 4 | youghal
# Processing Record 44 of Set 4 | sao felix do xingu
# Processing Record 45 of Set 4 | marzuq
# Processing Record 46 of Set 4 | usinsk
# Processing Record 47 of Set 4 | jutai
# Processing Record 48 of Set 4 | henties bay
# Processing Record 49 of Set 4 | ancud
# Processing Record 50 of Set 4 | havelock
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | vangaindrano
# Processing Record 3 of Set 5 | ratnagiri
# Processing Record 4 of Set 5 | faya
# Processing Record 5 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 5 | galle
# Processing Record 7 of Set 5 | laguna
# Processing Record 8 of Set 5 | talladega
# Processing Record 9 of Set 5 | vasto
# Processing Record 10 of Set 5 | umm kaddadah
# Processing Record 11 of Set 5 | altay
# Processing Record 12 of Set 5 | khodz
# Processing Record 13 of Set 5 | manati
# Processing Record 14 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 5 | saldanha
# Processing Record 16 of Set 5 | opuwo
# Processing Record 17 of Set 5 | roald
# Processing Record 18 of Set 5 | abapo
# Processing Record 19 of Set 5 | mikhaylovka
# Processing Record 20 of Set 5 | voljevac
# Processing Record 21 of Set 5 | savannah bight
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | nizwa
# Processing Record 24 of Set 5 | piacabucu
# Processing Record 25 of Set 5 | riachao das neves
# Processing Record 26 of Set 5 | leh
# Processing Record 27 of Set 5 | sisimiut
# Processing Record 28 of Set 5 | sitia
# Processing Record 29 of Set 5 | berlevag
# Processing Record 30 of Set 5 | port-gentil
# Processing Record 31 of Set 5 | guatire
# Processing Record 32 of Set 5 | puerto carreno
# Processing Record 33 of Set 5 | porto murtinho
# Processing Record 34 of Set 5 | mecca
# Processing Record 35 of Set 5 | campbellton
# Processing Record 36 of Set 5 | kirkenaer
# Processing Record 37 of Set 5 | gramoteino
# Processing Record 38 of Set 5 | hurzuf
# Processing Record 39 of Set 5 | neverkino
# Processing Record 40 of Set 5 | quatre cocos
# Processing Record 41 of Set 5 | mucurapo
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | salamiyah
# Processing Record 44 of Set 5 | conchas
# Processing Record 45 of Set 5 | abu kamal
# Processing Record 46 of Set 5 | olafsvik
# Processing Record 47 of Set 5 | sencha
# Processing Record 48 of Set 5 | winneba
# Processing Record 49 of Set 5 | gat
# Processing Record 50 of Set 5 | dire
# Processing Record 1 of Set 6 | le pradet
# Processing Record 2 of Set 6 | punta arenas
# Processing Record 3 of Set 6 | karachi
# Processing Record 4 of Set 6 | sur
# Processing Record 5 of Set 6 | moussoro
# Processing Record 6 of Set 6 | bonavista
# Processing Record 7 of Set 6 | omboue
# Processing Record 8 of Set 6 | eyl
# Processing Record 9 of Set 6 | bonfim
# Processing Record 10 of Set 6 | springdale
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | zamora
# Processing Record 13 of Set 6 | bandarbeyla
# Processing Record 14 of Set 6 | kargasok
# Processing Record 15 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 6 | jumla
# Processing Record 17 of Set 6 | geraldton
# Processing Record 18 of Set 6 | goderich
# Processing Record 19 of Set 6 | upernavik
# Processing Record 20 of Set 6 | neuquen
# Processing Record 21 of Set 6 | oleksandrivka
# Processing Record 22 of Set 6 | maniitsoq
# Processing Record 23 of Set 6 | mazara del vallo
# Processing Record 24 of Set 6 | aksu
# Processing Record 25 of Set 6 | alta floresta
# Processing Record 26 of Set 6 | narsaq
# Processing Record 27 of Set 6 | chipata
# Processing Record 28 of Set 6 | ocean city
# Processing Record 29 of Set 6 | matay
# Processing Record 30 of Set 6 | rocha
# Processing Record 31 of Set 6 | damaturu
# Processing Record 32 of Set 6 | gewane
# Processing Record 33 of Set 6 | carutapera
# Processing Record 34 of Set 6 | karlstad
# Processing Record 35 of Set 6 | arraial do cabo
# Processing Record 36 of Set 6 | barcelos
# Processing Record 37 of Set 6 | kosh-agach
# Processing Record 38 of Set 6 | shentala
# Processing Record 39 of Set 6 | hamilton
# Processing Record 40 of Set 6 | tskaltubo
# Processing Record 41 of Set 6 | krasnogvardeyskiy
# Processing Record 42 of Set 6 | motril
# Processing Record 43 of Set 6 | valdemarpils
# Processing Record 44 of Set 6 | reconquista
# Processing Record 45 of Set 6 | vallenar
# Processing Record 46 of Set 6 | ludvika
# Processing Record 47 of Set 6 | aquiraz
# Processing Record 48 of Set 6 | maceo
# Processing Record 49 of Set 6 | marsa matruh
# Processing Record 50 of Set 6 | brae
# Processing Record 1 of Set 7 | upata
# Processing Record 2 of Set 7 | emba
# Processing Record 3 of Set 7 | micheweni
# Processing Record 4 of Set 7 | puerto madryn
# Processing Record 5 of Set 7 | bermeo
# Processing Record 6 of Set 7 | knittelfeld
# Processing Record 7 of Set 7 | villarrica
# Processing Record 8 of Set 7 | jaisalmer
# Processing Record 9 of Set 7 | hangu
# Processing Record 10 of Set 7 | jensen beach
# Processing Record 11 of Set 7 | maslova pristan
# Processing Record 12 of Set 7 | bar harbor
# Processing Record 13 of Set 7 | dawlatabad
# Processing Record 14 of Set 7 | buchanan
# Processing Record 15 of Set 7 | grosuplje
# Processing Record 16 of Set 7 | iracoubo
# Processing Record 17 of Set 7 | los llanos de aridane
# Processing Record 18 of Set 7 | kruisfontein
# Processing Record 19 of Set 7 | socuellamos
# Processing Record 20 of Set 7 | jaciara
# Processing Record 21 of Set 7 | ville-marie
# Processing Record 22 of Set 7 | xuddur
# Processing Record 23 of Set 7 | qaqortoq
# Processing Record 24 of Set 7 | pangoa
# Processing Record 25 of Set 7 | baijiantan
# Processing Record 26 of Set 7 | bathsheba
# Processing Record 27 of Set 7 | boende
# Processing Record 28 of Set 7 | la jigua
# Processing Record 29 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 30 of Set 7 | saint-pierre
# Processing Record 31 of Set 7 | sosva
# Processing Record 32 of Set 7 | birjand
# Processing Record 33 of Set 7 | rabak
# Processing Record 34 of Set 7 | porbandar
# Processing Record 35 of Set 7 | lamu
# Processing Record 36 of Set 7 | uruzgan
# Processing Record 37 of Set 7 | novoagansk
# Processing Record 38 of Set 7 | termiz
# Processing Record 39 of Set 7 | ashington
# Processing Record 40 of Set 7 | sinnamary
# Processing Record 41 of Set 7 | tzucacab
# Processing Record 42 of Set 7 | kulhudhuffushi
# Processing Record 43 of Set 7 | po
# City not found. Skipping...
# Processing Record 44 of Set 7 | lagos
# Processing Record 45 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 46 of Set 7 | mampong
# Processing Record 47 of Set 7 | muros
# Processing Record 48 of Set 7 | vila do maio
# Processing Record 49 of Set 7 | umm bab
# Processing Record 50 of Set 7 | matias olimpio
# Processing Record 1 of Set 8 | nanga eboko
# Processing Record 2 of Set 8 | mvuma
# Processing Record 3 of Set 8 | matara
# Processing Record 4 of Set 8 | caernarfon
# Processing Record 5 of Set 8 | krasnokholm
# Processing Record 6 of Set 8 | fez
# Processing Record 7 of Set 8 | iranshahr
# Processing Record 8 of Set 8 | saint-francois
# Processing Record 9 of Set 8 | coquimbo
# Processing Record 10 of Set 8 | thurso
# Processing Record 11 of Set 8 | praia da vitoria
# Processing Record 12 of Set 8 | najran
# Processing Record 13 of Set 8 | sandane
# Processing Record 14 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 15 of Set 8 | dobryanka
# Processing Record 16 of Set 8 | corrente
# Processing Record 17 of Set 8 | ensley
# Processing Record 18 of Set 8 | thinadhoo
# Processing Record 19 of Set 8 | pitimbu
# Processing Record 20 of Set 8 | tiznit
# Processing Record 21 of Set 8 | tocopilla
# Processing Record 22 of Set 8 | plettenberg bay
# Processing Record 23 of Set 8 | ouesso
# Processing Record 24 of Set 8 | cayenne
# Processing Record 25 of Set 8 | moosburg
# Processing Record 26 of Set 8 | inhambane
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | kaniama
# Processing Record 29 of Set 8 | kandi
# Processing Record 30 of Set 8 | tafresh
# Processing Record 31 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 8 | mikkeli
# Processing Record 33 of Set 8 | lar
# Processing Record 34 of Set 8 | nesna
# Processing Record 35 of Set 8 | zhezkazgan
# Processing Record 36 of Set 8 | pennadam
# Processing Record 37 of Set 8 | grand-santi
# Processing Record 38 of Set 8 | bedesa
# Processing Record 39 of Set 8 | morondava
# Processing Record 40 of Set 8 | koslan
# Processing Record 41 of Set 8 | itaguai
# Processing Record 42 of Set 8 | log
# Processing Record 43 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 8 | hualmay
# Processing Record 45 of Set 8 | saint-leu
# Processing Record 46 of Set 8 | burica
# City not found. Skipping...
# Processing Record 47 of Set 8 | koryazhma
# Processing Record 48 of Set 8 | maxixe
# Processing Record 49 of Set 8 | muisne
# Processing Record 50 of Set 8 | cacoal
# Processing Record 1 of Set 9 | leninsk-kuznetskiy
# Processing Record 2 of Set 9 | thabazimbi
# Processing Record 3 of Set 9 | rovaniemi
# Processing Record 4 of Set 9 | kuusamo
# Processing Record 5 of Set 9 | kaoma
# Processing Record 6 of Set 9 | sao joao da barra
# Processing Record 7 of Set 9 | namibe
# Processing Record 8 of Set 9 | mingaora
# Processing Record 9 of Set 9 | joacaba
# Processing Record 10 of Set 9 | valdivia
# Processing Record 11 of Set 9 | tendukheda
# Processing Record 12 of Set 9 | east liverpool
# Processing Record 13 of Set 9 | hofn
# Processing Record 14 of Set 9 | san cristobal
# Processing Record 15 of Set 9 | tazovskiy
# Processing Record 16 of Set 9 | jardim
# Processing Record 17 of Set 9 | gazanjyk
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | kalmunai
# Processing Record 20 of Set 9 | isla mujeres
# Processing Record 21 of Set 9 | port hawkesbury
# Processing Record 22 of Set 9 | marabba
# Processing Record 23 of Set 9 | izacic
# Processing Record 24 of Set 9 | mehran
# Processing Record 25 of Set 9 | minab
# Processing Record 26 of Set 9 | rundu
# Processing Record 27 of Set 9 | klyuchi
# Processing Record 28 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 9 | strezhevoy
# Processing Record 30 of Set 9 | rabo de peixe
# Processing Record 31 of Set 9 | beterou
# Processing Record 32 of Set 9 | la baule-escoublac
# Processing Record 33 of Set 9 | nouadhibou
# Processing Record 34 of Set 9 | bandundu
# Processing Record 35 of Set 9 | pitsunda
# Processing Record 36 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 37 of Set 9 | caxito
# Processing Record 38 of Set 9 | hobe sound
# Processing Record 39 of Set 9 | tubuala
# Processing Record 40 of Set 9 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 42 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 9 | chingirlau
# Processing Record 44 of Set 9 | monatele
# City not found. Skipping...
# Processing Record 45 of Set 9 | antsohihy
# Processing Record 46 of Set 9 | joshimath
# Processing Record 47 of Set 9 | turukhansk
# Processing Record 48 of Set 9 | lesnikovo
# Processing Record 49 of Set 9 | dvinskoy
# Processing Record 50 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 10 | bethanien
# Processing Record 2 of Set 10 | anloga
# Processing Record 3 of Set 10 | kindu
# Processing Record 4 of Set 10 | callaway
# Processing Record 5 of Set 10 | windhoek
# Processing Record 6 of Set 10 | ihiala
# Processing Record 7 of Set 10 | aleksinac
# Processing Record 8 of Set 10 | saint-louis
# Processing Record 9 of Set 10 | general roca
# Processing Record 10 of Set 10 | storforshei
# Processing Record 11 of Set 10 | bequimao
# Processing Record 12 of Set 10 | chapais
# Processing Record 13 of Set 10 | ndele
# Processing Record 14 of Set 10 | guajara
# Processing Record 15 of Set 10 | san felipe
# Processing Record 16 of Set 10 | santa luzia
# Processing Record 17 of Set 10 | mekhe
# Processing Record 18 of Set 10 | koroni
# Processing Record 19 of Set 10 | obuasi
# Processing Record 20 of Set 10 | ayagoz
# Processing Record 21 of Set 10 | elesbao veloso
# Processing Record 22 of Set 10 | krasnoyarskiy
# Processing Record 23 of Set 10 | gurupi
# Processing Record 24 of Set 10 | igarka
# Processing Record 25 of Set 10 | sokoto
# Processing Record 26 of Set 10 | caldararu
# Processing Record 27 of Set 10 | wattegama
# Processing Record 28 of Set 10 | kutum
# Processing Record 29 of Set 10 | keti bandar
# Processing Record 30 of Set 10 | monte carmelo
# Processing Record 31 of Set 10 | kidal
# Processing Record 32 of Set 10 | bara
# Processing Record 33 of Set 10 | pemba
# Processing Record 34 of Set 10 | oussouye
# Processing Record 35 of Set 10 | annau
# Processing Record 36 of Set 10 | camacha
# Processing Record 37 of Set 10 | beira
# Processing Record 38 of Set 10 | belmonte
# Processing Record 39 of Set 10 | chicama
# Processing Record 40 of Set 10 | camana
# Processing Record 41 of Set 10 | yabelo
# Processing Record 42 of Set 10 | wum
# Processing Record 43 of Set 10 | gorele
# Processing Record 44 of Set 10 | veraval
# Processing Record 45 of Set 10 | the valley
# Processing Record 46 of Set 10 | santa maria
# Processing Record 47 of Set 10 | takoradi
# Processing Record 48 of Set 10 | ellisras
# Processing Record 49 of Set 10 | mandera
# Processing Record 50 of Set 10 | oranjemund
# Processing Record 1 of Set 11 | pisco
# Processing Record 2 of Set 11 | astana
# Processing Record 3 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 4 of Set 11 | carnarvon
# Processing Record 5 of Set 11 | bentiu
# Processing Record 6 of Set 11 | zyryanovsk
# Processing Record 7 of Set 11 | huntington
# Processing Record 8 of Set 11 | persianovskiy
# Processing Record 9 of Set 11 | sorland
# Processing Record 10 of Set 11 | kachiry
# Processing Record 11 of Set 11 | portalegre
# Processing Record 12 of Set 11 | acevedo
# Processing Record 13 of Set 11 | huruta
# Processing Record 14 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 11 | iqaluit
# Processing Record 17 of Set 11 | dhidhdhoo
# Processing Record 18 of Set 11 | guarapari
# Processing Record 19 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 20 of Set 11 | pinehurst
# Processing Record 21 of Set 11 | andujar
# Processing Record 22 of Set 11 | ambanja
# Processing Record 23 of Set 11 | harstad
# Processing Record 24 of Set 11 | belyy yar
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | beni suef
# Processing Record 27 of Set 11 | cockburn town
# Processing Record 28 of Set 11 | zaysan
# Processing Record 29 of Set 11 | nyazepetrovsk
# Processing Record 30 of Set 11 | korla
# Processing Record 31 of Set 11 | dondo
# Processing Record 32 of Set 11 | bulembu
# Processing Record 33 of Set 11 | dwarka
# Processing Record 34 of Set 11 | zabol
# Processing Record 35 of Set 11 | coihaique
# Processing Record 36 of Set 11 | boat of garten
# Processing Record 37 of Set 11 | vera cruz
# Processing Record 38 of Set 11 | amalapuram
# Processing Record 39 of Set 11 | plattsburgh
# Processing Record 40 of Set 11 | boa vista
# Processing Record 41 of Set 11 | yugorsk
# Processing Record 42 of Set 11 | muli
# Processing Record 43 of Set 11 | puerto varas
# Processing Record 44 of Set 11 | donduseni
# Processing Record 45 of Set 11 | natal
# Processing Record 46 of Set 11 | zastron
# Processing Record 47 of Set 11 | manta
# Processing Record 48 of Set 11 | horadiz
# Processing Record 49 of Set 11 | ginda
# Processing Record 50 of Set 11 | tabuk
# Processing Record 1 of Set 12 | fomboni
# Processing Record 2 of Set 12 | nenagh
# Processing Record 3 of Set 12 | ventanas
# Processing Record 4 of Set 12 | independence
# Processing Record 5 of Set 12 | lerwick
# Processing Record 6 of Set 12 | kolvereid
# Processing Record 7 of Set 12 | zverinogolovskoye
# Processing Record 8 of Set 12 | sabha
# Processing Record 9 of Set 12 | vuktyl
# Processing Record 10 of Set 12 | sept-iles
# Processing Record 11 of Set 12 | mangaluru
# Processing Record 12 of Set 12 | bubaque
# Processing Record 13 of Set 12 | ust-tsilma
# Processing Record 14 of Set 12 | abdanan
# Processing Record 15 of Set 12 | kapuskasing
# Processing Record 16 of Set 12 | baghdad
# Processing Record 17 of Set 12 | kaduy
# Processing Record 18 of Set 12 | mananjary
# Processing Record 19 of Set 12 | ouallam
# Processing Record 20 of Set 12 | nalut
# Processing Record 21 of Set 12 | doctor juan manuel frutos
# Processing Record 22 of Set 12 | necochea
# Processing Record 23 of Set 12 | beberibe
# Processing Record 24 of Set 12 | prieska
# Processing Record 25 of Set 12 | risod
# Processing Record 26 of Set 12 | aqtobe
# Processing Record 27 of Set 12 | tacoronte
# Processing Record 28 of Set 12 | natalio
# Processing Record 29 of Set 12 | bilma
# Processing Record 30 of Set 12 | sao jose do belmonte
# Processing Record 31 of Set 12 | itacare
# Processing Record 32 of Set 12 | lambare
# Processing Record 33 of Set 12 | guapiles
# Processing Record 34 of Set 12 | brest
# Processing Record 35 of Set 12 | talavera
# Processing Record 36 of Set 12 | tambopata
# Processing Record 37 of Set 12 | cap-aux-meules
# Processing Record 38 of Set 12 | kottagudem
# Processing Record 39 of Set 12 | kannangad
# Processing Record 40 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 41 of Set 12 | contamana
# Processing Record 42 of Set 12 | ubinskoye
# Processing Record 43 of Set 12 | tessalit
# Processing Record 44 of Set 12 | lima
# Processing Record 45 of Set 12 | livingstone
# Processing Record 46 of Set 12 | sosua
# Processing Record 47 of Set 12 | alakurtti
# Processing Record 48 of Set 12 | trairi
# Processing Record 49 of Set 12 | timoteo
# Processing Record 50 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 13 | paralimni
# Processing Record 2 of Set 13 | puerto ayora
# Processing Record 3 of Set 13 | olinda
# Processing Record 4 of Set 13 | skhisma
# Processing Record 5 of Set 13 | umm lajj
# Processing Record 6 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 13 | concepcion
# Processing Record 8 of Set 13 | san carlos de bariloche
# Processing Record 9 of Set 13 | shubarshi
# Processing Record 10 of Set 13 | timizart
# Processing Record 11 of Set 13 | bonthe
# Processing Record 12 of Set 13 | makurdi
# Processing Record 13 of Set 13 | benguela
# Processing Record 14 of Set 13 | harper
# Processing Record 15 of Set 13 | gamba
# Processing Record 16 of Set 13 | grand gaube
# Processing Record 17 of Set 13 | springbok
# Processing Record 18 of Set 13 | nola
# Processing Record 19 of Set 13 | ipixuna
# Processing Record 20 of Set 13 | sebastian
# Processing Record 21 of Set 13 | shahrud
# Processing Record 22 of Set 13 | saint-honore
# Processing Record 23 of Set 13 | fonte boa
# Processing Record 24 of Set 13 | fatehpur
# Processing Record 25 of Set 13 | posevnaya
# Processing Record 26 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 27 of Set 13 | makokou
# Processing Record 28 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 13 | damghan
# Processing Record 30 of Set 13 | nuuk
# Processing Record 31 of Set 13 | bowmore
# Processing Record 32 of Set 13 | alegrete
# Processing Record 33 of Set 13 | malaia
# Processing Record 34 of Set 13 | selty
# Processing Record 35 of Set 13 | kahama
# Processing Record 36 of Set 13 | can
# Processing Record 37 of Set 13 | esna
# Processing Record 38 of Set 13 | sehithwa
# Processing Record 39 of Set 13 | ihosy
# Processing Record 40 of Set 13 | salta
# Processing Record 41 of Set 13 | guaymango
# Processing Record 42 of Set 13 | seredka
# Processing Record 43 of Set 13 | sembe
# Processing Record 44 of Set 13 | uarini
# Processing Record 45 of Set 13 | moroni
# Processing Record 46 of Set 13 | jalu
# Processing Record 47 of Set 13 | pao de acucar
# Processing Record 48 of Set 13 | arrecife
# Processing Record 49 of Set 13 | bereda
# Processing Record 50 of Set 13 | kedrovyy
# Processing Record 1 of Set 14 | jaguarao
# Processing Record 2 of Set 14 | nsoko
# Processing Record 3 of Set 14 | oriximina
# Processing Record 4 of Set 14 | coari
# Processing Record 5 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 14 | bonanza
# Processing Record 7 of Set 14 | rozhyshche
# Processing Record 8 of Set 14 | saint-georges
# Processing Record 9 of Set 14 | talnakh
# Processing Record 10 of Set 14 | niquelandia
# Processing Record 11 of Set 14 | guardiagrele
# Processing Record 12 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 14 | manali
# Processing Record 14 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 15 of Set 14 | miraflores
# Processing Record 16 of Set 14 | stromness
# Processing Record 17 of Set 14 | krasnoselkup
# Processing Record 18 of Set 14 | porto santo
# Processing Record 19 of Set 14 | santo antonio do ica
# Processing Record 20 of Set 14 | aleksandrovskoye
# Processing Record 21 of Set 14 | tharad
# Processing Record 22 of Set 14 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 23 of Set 14 | nisia floresta
# Processing Record 24 of Set 14 | novyy urengoy
# Processing Record 25 of Set 14 | diego de almagro
# Processing Record 26 of Set 14 | isiro
# Processing Record 27 of Set 14 | schwandorf
# Processing Record 28 of Set 14 | aswan
# Processing Record 29 of Set 14 | krasnoborsk
# Processing Record 30 of Set 14 | gondomar
# Processing Record 31 of Set 14 | praia
# Processing Record 32 of Set 14 | tromso
# Processing Record 33 of Set 14 | soyo
# Processing Record 34 of Set 14 | lokvine
# Processing Record 35 of Set 14 | masunga
# Processing Record 36 of Set 14 | pangody
# Processing Record 37 of Set 14 | le vauclin
# Processing Record 38 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 14 | suzun
# Processing Record 40 of Set 14 | palora
# Processing Record 41 of Set 14 | rawson
# Processing Record 42 of Set 14 | mamou
# Processing Record 43 of Set 14 | rosetta
# Processing Record 44 of Set 14 | macapa
# Processing Record 45 of Set 14 | aljustrel
# Processing Record 46 of Set 14 | ebebiyin
# Processing Record 47 of Set 14 | cobija
# Processing Record 48 of Set 14 | comodoro rivadavia
# Processing Record 49 of Set 14 | kisangani
# Processing Record 50 of Set 14 | jacksonville beach
# Processing Record 1 of Set 15 | naugarzan
# City not found. Skipping...
# Processing Record 2 of Set 15 | buritizeiro
# Processing Record 3 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 15 | risor
# Processing Record 5 of Set 15 | coro
# Processing Record 6 of Set 15 | tabou
# Processing Record 7 of Set 15 | nordhausen
# Processing Record 8 of Set 15 | niamtougou
# Processing Record 9 of Set 15 | virginia beach
# Processing Record 10 of Set 15 | pimentel
# Processing Record 11 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 12 of Set 15 | ico
# Processing Record 13 of Set 15 | farnham
# Processing Record 14 of Set 15 | develi
# Processing Record 15 of Set 15 | zabid
# Processing Record 16 of Set 15 | durres
# Processing Record 17 of Set 15 | la seyne-sur-mer
# Processing Record 18 of Set 15 | chake chake
# Processing Record 19 of Set 15 | mbandaka
# Processing Record 20 of Set 15 | manjacaze
# Processing Record 21 of Set 15 | fontem
# Processing Record 22 of Set 15 | ponta delgada
# Processing Record 23 of Set 15 | sechenovo
# Processing Record 24 of Set 15 | kambove
# Processing Record 25 of Set 15 | aksarayskiy
# Processing Record 26 of Set 15 | punta gorda
# Processing Record 27 of Set 15 | mweka
# Processing Record 28 of Set 15 | san martin
# Processing Record 29 of Set 15 | muzhi
# Processing Record 30 of Set 15 | soure
# Processing Record 31 of Set 15 | el alto
# Processing Record 32 of Set 15 | abeche
# Processing Record 33 of Set 15 | maceio
# Processing Record 34 of Set 15 | zambezi
# Processing Record 35 of Set 15 | novomyrhorod
# Processing Record 36 of Set 15 | cascais
# Processing Record 37 of Set 15 | peniche
# Processing Record 38 of Set 15 | grenada
# Processing Record 39 of Set 15 | japura
# Processing Record 40 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 41 of Set 15 | gainesville
# Processing Record 42 of Set 15 | bagua grande
# Processing Record 43 of Set 15 | luau
# Processing Record 44 of Set 15 | richards bay
# Processing Record 45 of Set 15 | kisesa
# Processing Record 46 of Set 15 | purgstall
# Processing Record 47 of Set 15 | mazyr
# Processing Record 48 of Set 15 | oppdal
# Processing Record 49 of Set 15 | guajara-mirim
# City not found. Skipping...
# Processing Record 50 of Set 15 | antofagasta
# Processing Record 1 of Set 16 | westport
# Processing Record 2 of Set 16 | yining
# Processing Record 3 of Set 16 | tortosa
# Processing Record 4 of Set 16 | bobenheim-roxheim
# Processing Record 5 of Set 16 | una
# Processing Record 6 of Set 16 | nelidovo
# Processing Record 7 of Set 16 | aleksandrov gay
# Processing Record 8 of Set 16 | senanga
# Processing Record 9 of Set 16 | imbituba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 700

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Garowe   8.4054  48.4845     78.96        35           0
# 1  Krasnoshchekovo  51.6708  82.7289     19.83        80          89
# 2    Mar Del Plata -38.0023 -57.5575     68.88        97         100
# 3       Fuengirola  36.5400  -4.6247     46.85        93          20
# 4          Husavik  66.0449 -17.3389     27.52        92         100
# 5      Port Alfred -33.5906  26.8910     75.87        74          41
# 6          Ushuaia -54.8000 -68.3000     44.26        65          75
# 7     Ponta Do Sol  32.6667 -17.1000     59.72        61          31
# 8   Cap Malheureux -19.9842  57.6142     81.46        82          98
# 9         Tasiilaq  65.6145 -37.6368     11.93        92         100
#
#    Wind Speed Country                 Date Current Description
# 0       15.88      SO  2023-01-31 07:58:01           clear sky
# 1        1.90      RU  2023-01-31 07:58:01     overcast clouds
# 2        3.44      AR  2023-01-31 07:57:11                 fog
# 3       11.50      ES  2023-01-31 07:58:01          few clouds
# 4       28.88      IS  2023-01-31 07:58:02          light snow
# 5       21.65      ZA  2023-01-31 07:58:02    scattered clouds
# 6        3.44      AR  2023-01-31 07:58:02       broken clouds
# 7        5.64      PT  2023-01-31 07:58:03    scattered clouds
# 8        1.99      MU  2023-01-31 07:49:18          light rain
# 9        1.01      GL  2023-01-31 07:58:03          light snow

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City","Country", "Lat", "Lng", 'Max Temp', 'Humidity', "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df= city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Garowe      SO   8.4054  48.4845     78.96        35           0
# 1  Krasnoshchekovo      RU  51.6708  82.7289     19.83        80          89
# 2    Mar Del Plata      AR -38.0023 -57.5575     68.88        97         100
# 3       Fuengirola      ES  36.5400  -4.6247     46.85        93          20
# 4          Husavik      IS  66.0449 -17.3389     27.52        92         100
# 5      Port Alfred      ZA -33.5906  26.8910     75.87        74          41
# 6          Ushuaia      AR -54.8000 -68.3000     44.26        65          75
# 7     Ponta Do Sol      PT  32.6667 -17.1000     59.72        61          31
# 8   Cap Malheureux      MU -19.9842  57.6142     81.46        82          98
# 9         Tasiilaq      GL  65.6145 -37.6368     11.93        92         100
#
#    Wind Speed Current Description
# 0       15.88           clear sky
# 1        1.90     overcast clouds
# 2        3.44                 fog
# 3       11.50          few clouds
# 4       28.88          light snow
# 5       21.65    scattered clouds
# 6        3.44       broken clouds
# 7        5.64    scattered clouds
# 8        1.99          light rain
# 9        1.01          light snow

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
